# %% [markdown]
# **Importando dados**

# %%
#importando a biblioteca pandas
import pandas as pd

# %%
#atribui a variável 'alugueis' a função de ler um CSV com o valor de alugueis em diferentes localidades
alugueis = pd.read_csv('aluguel.csv', delimiter=';')

# %% [markdown]
# outras funções de importação de dados do pandas:
#
# *read_excel()*: Lê um arquivo .xls
#
# *read_json()*: Lê arquivos JSON
#
# *read_html()*:  Lê tabelas HTML
#
# *read_sql()*: Lê dados de um banco de dados relacional, como o MySQL, PostgreSQL e SQL Server

# %%
#função head(10) retorna as primeiras 10 linhas da tabela
alugueis.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
#função head(10) retorna as primeiras 10 linhas da tabela
alugueis.tail(10)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32950    28   1000.0       360.0    25.0
# ...

# %% [markdown]
# **explorando linhas e colunas**

# %%
#retorna uma tupla com a quantidade de linhas e colunas
alugueis.shape
# Out:
# (32960, 9)

# %%
#retorna o nome de todas as colunas
alugueis.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
#retorna informações úteis para cada coluna
#exemplo: número de dados núlos, tipo de dado.
alugueis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
#retorna apenas os dados da coluna especificada
alugueis['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
#visualiza mais de uma coluna juntamente em um dataframe
alugueis[['Quartos', 'Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# ***Desafios***

# %% [markdown]
# 1) Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.
#
# 2) Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.
#
# 3) Confira a quantidade de linhas e colunas desse DataFrame.
#
# 4) Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.
#
# Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc). Dica: pesquise pelo método describe.

# %%
#lendo a URL com notas de alunos
url_alunos = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv"
alunos = pd.read_csv(url_alunos, delimiter=',')

# %%
#visualizando as primeiras 7 linhas
alunos.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
#visualizando as ultimas 5 linhas
alunos.tail(5)
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %%
#conferindo a quantidade de linhas e colunas
alunos.shape
# Out:
# (18, 4)

# %%
#conferindo as colunas do dataframe e seus tipos de dados
alunos.columns
# Out:
# Index(['Nome', 'Idade', 'Notas', 'Aprovado'], dtype='object')

# %%
#conferindo as informações de uma coluna específica
alunos["Nome"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 18 entries, 0 to 17
# Series name: Nome
# Non-Null Count  Dtype
# --------------  -----
# 18 non-null     object
# dtypes: object(1)
# memory usage: 276.0+ bytes

# %%
#usando a função describe() para conseguir métricas como contagem total, média, e variação
alunos.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# *explicação*
#
# Count: Conta o número de valores não nulos em uma coluna, útil para detectar dados faltantes.
#
#
# Mean: Média aritmética dos valores, mas pode ser distorcida por valores extremos.
#
#
# Std: Desvio padrão, mede a dispersão dos dados em relação à média.
#
#
# Min e Max: Valores mínimo e máximo da amostra, indicando a amplitude dos dados.
#
#
# Quartis: Valores que dividem os dados em partes iguais, como a mediana (50%), que indica o valor que separa metade dos dados.

# %% [markdown]
# **Análise exploratória de dados**

# %% [markdown]
# Qual o valor médio de aluguél por tipo de imóvel?

# %%
alugueis.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
#calcula a média de todos os valores e arredonda
round(alugueis['Valor'].mean())
# Out:
# 12953

# %%
#agroupa pela coluna 'Tipo' e retorna a média de todos os dados numéricos
alugueis.groupby('Tipo').mean(numeric_only=True)
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
#calcula média de valor de cada tipo de imóvel, ordenando pelo valor
alugueis.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
#atribui a uma variável 
df_preco_tipo = alugueis.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

#exibe um gráfico de tipo barh (barras horizontais), com tamanho e cor determinados
df_preco_tipo.plot(kind='barh', figsize=(12, 6), color='red')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[44], line 5
#       2 df_preco_tipo = alugueis.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
#       4 #exibe um gráfico de tipo barh (barras horizontais), com tamanho e cor determinados
# ----> 5 df_preco_tipo.plot(kind='barh', figsize=(12, 6), color='red')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#
# ...

# %% [markdown]
# **Removendo os imóveis comerciais**
#
# Não queremos imóveis comerciais no nosso dataset devido ao seu alto preço

# %%
#retorna todo único nome de tipo de imóvel
alugueis.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
#serparando os imóveis comerciais
imoveis_comerciais = ['Conjunto Comercial/Sala', 
                      'Prédio Inteiro', 'Loja/Salão', 
                      'Galpão/Depósito/Armazém', 
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
#retorna todos os imóveis comerciais 
alugueis.query('@imoveis_comerciais in Tipo')
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
#atribui a uma variável os imóveis não comerciais
nao_comerciais = alugueis.query('@imoveis_comerciais not in Tipo')
nao_comerciais.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
#retorna todos os tipos de imóveis, que agora não possuem imóveis comerciais
nao_comerciais.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
#atribui a uma variável o novo dataset
df_preco_tipo = nao_comerciais.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

#exibe um gráfico de tipo barh (barras horizontais), com tamanho e cor determinados
df_preco_tipo.plot(kind='barh', figsize=(12, 6), color='red')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# **Qual o percentual de cada imóvel em nossa base de dados?**

# %%
#retorna todos os tipos únicos de imóveis
nao_comerciais.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
#conta os valores de cada tipo de imóvel e retorna o valor percentual
nao_comerciais.Tipo.value_counts(normalize=True).to_frame().sort_values('proportion')
# Out:
#                     proportion
# Tipo
# Studio                0.000173
# Loft                  0.002207
# Casa de Vila          0.010774
# Flat                  0.020596
# Quitinete             0.036173
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Apartamento           0.845139

# %%
from turtle import color

#atribui o dataframe a uma variável
nao_comerciais_percentual_tipo = nao_comerciais.Tipo.value_counts(normalize=True).to_frame().sort_values('proportion')

#exibe um gráfico de barras, com tamanho determinado, cor vermelha, e rotulando as coordenadas X e Y
nao_comerciais_percentual_tipo.plot(kind='bar', figsize=(12, 5), color='red', xlabel='Tipos', ylabel='Porcentagem')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentagem'>

# %% [markdown]
# **Selecionando apenas imóveis do tipo apartamento**

# %%
#retorna apenas imóveis do tipo 'Apartamento'
apartamentos = nao_comerciais.query('Tipo == "Apartamento"')
apartamentos.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %%
#calcula a média de quartos por apartamento e arredonda o valor
round(apartamentos['Quartos'].mean(), 2)
# Out:
# 2.48

# %%
#conta quantos quartos únicos existem na base de dados
apartamentos['Quartos'].count()
# Out:
# 19532

# %%
#retorna o valor de aluguel de cada bairro, ordenando por menor valor e selecionando os 5 mais caros
apartamentos_valores = apartamentos.groupby('Bairro')['Valor'].mean().to_frame().sort_values('Valor').tail()

# %%
#retorna o gráfico da consulta
apartamentos_valores.plot(kind='barh', figsize=(12, 8), color='red')
# Out:
# <Axes: ylabel='Bairro'>

# %% [markdown]
# **Tratando e filtrando os dados**

# %% [markdown]
# Lidando com dados nulos

# %%
#retorna todas as linhas, indicando se os valores são nulos ou não
apartamentos.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# 6      False   False    False  False   False  False  False       False  False
# 10     False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32951  False   False    False  False   False  False  False       False   True
# 32953  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [19532 rows x 9 columns]

# %%
#mostra a quantidade total de valores nulos por coluna
apartamentos.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
#substitui os valores nulos por 0
apartamentos.fillna(0)
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   0.0
# ...

# %%
#atribui para a variável alugueis
apartamentos = apartamentos.fillna(0)

# %%
#mostra a quantidade total de valores nulos por coluna
#não há mais valores nulos
apartamentos.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# *Removendo registros*

# %%
#retorna todas as linhas em que a coluna Valor ou Condominio são iguais a 0
apartamentos.query('Valor == 0 or Condominio == 0')
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 76     Apartamento  Barra da Tijuca        2      1       1    70     0.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             0.0   0.0
# 10            0.0   0.0
# ...

# %%
#retorna o index de todas essas linhas com valores negativos
apartamentos.query('Valor == 0 or Condominio == 0').index
# Out:
# Index([    5,    10,    76,   113,   166,   194,   258,   265,   275,   292,
#        ...
#        32420, 32438, 32480, 32538, 32584, 32609, 32643, 32666, 32708, 32809],
#       dtype='int64', length=752)

# %%
#atribui os index a uma variavel
registros_a_remover = apartamentos.query('Valor == 0 or Condominio == 0').index

# %%
#remove todas as LINHAS desses indexes
#inplace=true faz com que a alteração seja definitiva
apartamentos.drop(registros_a_remover, axis=0, inplace=True)

# %%
#agora não há mais valores com zero em 'valor' ou 'condominio'
apartamentos.query('Valor == 0 or Condominio == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
#retorna o cabeçalho
apartamentos.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU
# 3   20.0
# 4    0.0
# 6   17.0
# 11  74.0
# 12  14.0

# %%
#retorna todos os tipos de alugueis
#agora não precisamos mais da coluna 'tipo', já que todos os imóveis são apartamentos
apartamentos.Tipo.unique()
# Out:
# array(['Apartamento'], dtype=object)

# %%
#remove a COLUNA "Tipo", deixando a alteração definitiva
apartamentos.drop('Tipo', axis=1, inplace=True)

# %%
#retorna o cabeçalho do df
#agora não temos mais a coluna 'Tipo'
apartamentos.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU
# 3   20.0
# 4    0.0
# 6   17.0
# 11  74.0
# 12  14.0

# %% [markdown]
# **Filtrando dados**

# %% [markdown]
# 1. *Apartamentos que possuem 1 quarto e aluguel menor que 1200*

# %%
apartamentos['Quartos'] == 1
# Out:
#   Cell In[124], line 1
#     apartamentos['Quartos'] == 1.plot()
#                                 ^
# SyntaxError: invalid decimal literal

# %%
selecao1 = apartamentos['Quartos'] == 1

# %%
apartamentos[selecao1]
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 28              Tijuca        1      0       0    48   750.0       772.0
# 54              Centro        1      0       0    27   750.0       371.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32918          Ipanema        1      0       0    55  2000.0       630.0
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 3       20.0
# 4        0.0
# 13      50.0
# 28      25.0
# 54      19.0
# ...

# %%
selecao2 = apartamentos['Valor'] < 1200

# %%
apartamentos[selecao2]
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 28                      Tijuca        1      0       0    48   750.0
# ...                        ...      ...    ...     ...   ...     ...
# 32925                 Campinho        2      0       0    63   800.0
# 32930  Freguesia (Jacarepaguá)        2      1       0    60   500.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    0.0
# 19          300.0   28.0
# 23          670.0    0.0
# ...

# %%
selecao_final = (selecao1) & (selecao2)
apartamentos[selecao_final]
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
apartamentos1 = apartamentos[selecao_final]

# %% [markdown]
# 2. *Apartamentos que possuem pelo menos 2 quartos, aluguel menor que 300 e area maior que 70

# %%
selecao = (apartamentos['Quartos'] >= 2) & (apartamentos['Valor'] < 3000) & (apartamentos['Area'] > 70)
apartamentos[selecao]
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 12          Lins de Vasconcelos        3      1       1    90  1500.0
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 36     Recreio dos Bandeirantes        3      1       1   105  2300.0
# ...                         ...      ...    ...     ...   ...     ...
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
# 32941           Barra da Tijuca        3      2       0    98  2300.0
# 32944  Recreio dos Bandeirantes        3      2       1    88  1550.0
# 32956               Jacarepaguá        3      1       2    78  1800.0
#
#        Condominio   IPTU
# 12          455.0   14.0
# 21          700.0  138.0
# 24          700.0    0.0
# ...

# %%
apartamentos2 = apartamentos[selecao]

# %% [markdown]
# **Salvando os dados**

# %%
apartamentos.to_csv('dados_apartamentos.csv')

# %%
pd.read_csv('dados_apartamentos.csv')
# Out:
#        Unnamed: 0                Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0               3                Centro        1      0       0    15   800.0
# 1               4          Higienópolis        1      0       0    48   800.0
# 2               6              Cachambi        2      0       0    50  1300.0
# 3              11                Grajaú        2      1       0    70  1500.0
# 4              12   Lins de Vasconcelos        3      1       1    90  1500.0
# ...           ...                   ...      ...    ...     ...   ...     ...
# 18775       32951        Vila Valqueire        2      0       0    52  1000.0
# 18776       32953                 Méier        2      0       0    70   900.0
# 18777       32956           Jacarepaguá        3      1       2    78  1800.0
# 18778       32957  São Francisco Xavier        2      1       0    48  1400.0
# 18779       32958                Leblon        2      0       0    70  3000.0
#
#        Condominio  IPTU
# ...

# %%
apartamentos.to_csv('dados_apartamentos.csv', index=False, sep=';')

# %%
pd.read_csv('dados_apartamentos.csv', delimiter=';')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2                  Cachambi        2      0       0    50  1300.0       301.0
# 3                    Grajaú        2      1       0    70  1500.0       642.0
# 4       Lins de Vasconcelos        3      1       1    90  1500.0       455.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 18775        Vila Valqueire        2      0       0    52  1000.0       550.0
# 18776                 Méier        2      0       0    70   900.0       490.0
# 18777           Jacarepaguá        3      1       2    78  1800.0       800.0
# 18778  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 18779                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %%
apartamentos1.to_csv('apartamentos_pequenos.csv', sep=';', index=False)

# %%
pd.read_csv('apartamentos_pequenos.csv', delimiter=';')
# Out:
#            Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 0          Centro        1      0       0    15   800.0       390.0   20.0
# 1    Higienópolis        1      0       0    48   800.0       230.0    0.0
# 2          Tijuca        1      0       0    48   750.0       772.0   25.0
# 3          Centro        1      0       0    27   750.0       371.0   19.0
# 4          Centro        1      1       0    37  1100.0       540.0  900.0
# ..            ...      ...    ...     ...   ...     ...         ...    ...
# 494        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 495     Pechincha        1      0       1    69   900.0       640.0  126.0
# 496        Glória        1      0       0    46  1100.0       453.0   32.0
# 497      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 498        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
apartamentos2.to_csv('apartamentos_grandes.csv', sep=';', index=False)

# %%
pd.read_csv('apartamentos_grandes.csv', delimiter=';')
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0          Lins de Vasconcelos        3      1       1    90  1500.0
# 1                       Tijuca        2      1       0   110  1900.0
# 2                       Tijuca        2      1       0    78  2000.0
# 3                     Botafogo        2      1       0    76  2500.0
# 4     Recreio dos Bandeirantes        3      1       1   105  2300.0
# ...                        ...      ...    ...     ...   ...     ...
# 4454               Jacarepaguá        2      1       1    78  2200.0
# 4455           Barra da Tijuca        2      1       1    85  2250.0
# 4456           Barra da Tijuca        3      2       0    98  2300.0
# 4457  Recreio dos Bandeirantes        3      2       1    88  1550.0
# 4458               Jacarepaguá        3      1       2    78  1800.0
#
#       Condominio   IPTU
# 0          455.0   14.0
# 1          700.0  138.0
# 2          700.0    0.0
# 3          740.0    0.0
# ...

# %% [markdown]
# **Desafios**
# usando o arquivos alunos.csv

# %% [markdown]
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.

# %%
alunos_csv = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
alunos = pd.read_csv(alunos_csv)

# %%
alunos.head(10)
# Out:
#      Nome  Idade  Notas  Aprovado
# 0     Ary     20    7.5      True
# 1     Ana     18    NaN     False
# 2   Cátia     27    2.5     False
# 3   Denis     18    5.0     False
# 4    Beto     21   10.0      True
# 5   Bruna     23    NaN     False
# 6    Dara     21    7.0      True
# 7  Carlos     19    6.0      True
# 8   Alice     35    5.6     False
# 9   Vitor     28    NaN     False

# %%
alunos.isnull()
# Out:
#      Nome  Idade  Notas  Aprovado
# 0   False  False  False     False
# 1   False  False   True     False
# 2   False  False  False     False
# 3   False  False  False     False
# 4   False  False  False     False
# 5   False  False   True     False
# 6   False  False  False     False
# 7   False  False  False     False
# 8   False  False  False     False
# 9   False  False   True     False
# 10  False  False   True     False
# 11  False  False  False     False
# 12  False  False  False     False
# 13  False  False  False     False
# 14  False  False   True     False
# 15  False  False  False     False
# 16  False  False   True     False
# 17  False  False  False     False

# %%
#dados nulos tratados
alunos.fillna(0).sum()
# Out:
# Nome        AryAnaCátiaDenisBetoBrunaDaraCarlosAliceVitorD...
# Idade                                                     459
# Notas                                                    81.6
# Aprovado                                                    8
# dtype: object

# %%
alunos_quit = alunos.query("Nome == 'Alice' or Nome == 'Carlos'")
# Out:
#      Nome  Idade  Notas  Aprovado
# 7  Carlos     19    6.0      True
# 8   Alice     35    5.6     False

# %%
alunos.drop(alunos_quit, axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 alunos.drop(alunos_quit, axis=0, inplace=True)
#
# NameError: name 'alunos_quit' is not defined
