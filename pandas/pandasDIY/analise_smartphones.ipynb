# %%
#importando biblioteca pandas
import pandas as pd

# %%
#lendo o arquivo CSV
phones = pd.read_csv('smartphones.csv')

# %%
#imprime o cabeçalho do database
phones.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price
# 0   8.0    256.0  Yellow  Yes       231.60
# 1   4.0    128.0    Blue  Yes       279.00
# 2   4.0    128.0    Blue  Yes       179.01
# 3   6.0    128.0    Gray  Yes       279.99
# 4  12.0    512.0   White  Yes       799.00

# %% [markdown]
# Adicionar nova coluna "category"

# %%
#cria a coluna "category", aplicando diferentes labels de acordo com o preço do smartphone, utilizando a função lambda 
phones['Category'] = phones.apply(
    lambda row: "Flagship" if row['Final Price'] >= 699 else 
                "Mid-range" if (row['Final Price'] < 699) & (row['Final Price'] >= 299) else  
                "Budget" if row['Final Price'] < 299 else 
                "unknown", axis=1
)

# %%
#imprime as colunas do database (agora com 'category')
print(phones.columns)
# Out:
# Index(['Smartphone', 'Brand', 'Model', 'RAM', 'Storage', 'Color', 'Free',
#        'Final Price', 'Category'],
#       dtype='object')

# %%
#imprime o cabeçalho do database
phones.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price  Category
# 0   8.0    256.0  Yellow  Yes       231.60    Budget
# 1   4.0    128.0    Blue  Yes       279.00    Budget
# 2   4.0    128.0    Blue  Yes       179.01    Budget
# 3   6.0    128.0    Gray  Yes       279.99    Budget
# 4  12.0    512.0   White  Yes       799.00  Flagship

# %% [markdown]
# Tratando dados nulos

# %%
#retorna a soma de todos os resultados nulos para cada coluna
phones.isnull().sum()
# Out:
# Smartphone       0
# Brand            0
# Model            0
# RAM            483
# Storage         25
# Color            0
# Free             0
# Final Price      0
# Category         0
# dtype: int64

# %%
#remove todas as linhas com dados nulos e aplica definitivamente
phones.dropna(inplace=True)

# %%
#retorna a soma de todos os resultados nulos para cada coluna
phones.isnull().sum()
# Out:
# Smartphone     0
# Brand          0
# Model          0
# RAM            0
# Storage        0
# Color          0
# Free           0
# Final Price    0
# Category       0
# dtype: int64

# %% [markdown]
# Adicionar coluna "description"

# %%
#cria a coluna 'Description' que soma uma série de colunas e strings
phones['Description'] = phones['Brand'] + " " + phones['Model'] + " with " + phones['RAM'].astype(int).astype(str) + "GB of RAM and " + phones['Storage'].astype(int).astype(str) + "GB of storage in the " + phones['Color'] + " Color"

# %%
#imprime o cabeçalho do dataframe
phones.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price  Category  \
# 0   8.0    256.0  Yellow  Yes       231.60    Budget
# 1   4.0    128.0    Blue  Yes       279.00    Budget
# 2   4.0    128.0    Blue  Yes       179.01    Budget
# 3   6.0    128.0    Gray  Yes       279.99    Budget
# 4  12.0    512.0   White  Yes       799.00  Flagship
#
#                                          Description
# 0  Realme C55 with 8GB of RAM and 256GB of storag...
# 1  Samsung Galaxy M23 with 4GB of RAM and 128GB o...
# 2  Motorola Moto G13 with 4GB of RAM and 128GB of...
# 3  Xiaomi Redmi Note 11S with 6GB of RAM and 128G...
# 4  Nothing Phone (2) with 12GB of RAM and 512GB o...

# %%
#soma de celulares na categoria 'budget'
len(phones.query("Category == 'Budget'"))
# Out:
# 699

# %%
#soma de celulares na categoria 'mid-range'
len(phones.query("Category == 'Mid-range'"))
# Out:
# 475

# %%
#soma de celulares na categoria 'Flagship'
len(phones.query("Category == 'Flagship'"))
# Out:
# 159

# %% [markdown]
# Média dos preços

# %%
#imprime a média arredondada do preço final dos smartphones
round(phones['Final Price'].mean(), 2)
# Out:
# 380.27

# %% [markdown]
# Celulares com maior capacidade de armazenamento

# %%
#atribui a uma variável o(s) celulares com a maior capacidade de armazenamento
maior_armazenamento = phones['Storage'].max()

# %%
#retorna todos os celulares com esse armazenamento (512gb)
maiores_armazenamentos = phones.query("Storage == @maior_armazenamento")
maiores_armazenamentos
# Out:
#                                              Smartphone    Brand  \
# 4               Nothing Phone (2) 12/512GB Blanco Libre  Nothing
# 32    Realme 11 Pro Plus 5G 12/512GB Amoled FHD+ Cur...   Realme
# 43    Realme 11 Pro Plus 5G 12/512GB Amoled FHD+ Cur...   Realme
# 95         Nothing Phone (2) 12/512GB Gris Oscuro Libre  Nothing
# 477   Samsung Galaxy Z Fold4 12/512GB Negro Libre + ...  Samsung
# 661   Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
# 753         Samsung Galaxy Z Fold4 12/512GB Negro Libre  Samsung
# 983   Samsung Galaxy Z Fold4 12/512GB Negro Libre + ...  Samsung
# 1106          Samsung Galaxy Z Flip4 8/512GB Gris Libre  Samsung
# 1225              Oppo Find X2 Pro 12/512GB Negro Libre     OPPO
# 1456            Oppo Find X2 Pro 12/512GB Naranja Libre     OPPO
# 1579   Samsung Galaxy S22 Ultra 5G 12/512GB Negro Libre  Samsung
# 1580   Samsung Galaxy S22 Ultra 5G 12/512GB Verde Libre  Samsung
# 1603  Samsung Galaxy Z Flip4 8/512GB Azul Libre Vers...  Samsung
# 1604  Samsung Galaxy Z Flip4 8/512GB Gris Libre Vers...  Samsung
# 1794  Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
#
#                Model   RAM  Storage   Color Free  Final Price   Category  \
# 4          Phone (2)  12.0    512.0   White  Yes       799.00   Flagship
# 32            11 Pro  12.0    512.0   White  Yes       521.60  Mid-range
# 43            11 Pro  12.0    512.0   Black  Yes       521.60  Mid-range
# 95         Phone (2)  12.0    512.0    Gray  Yes       799.00   Flagship
# 477   Galaxy Z Fold4  12.0    512.0   Black  Yes      1919.00   Flagship
# 661   Galaxy Z Fold4  12.0    512.0   Green  Yes      1919.00   Flagship
# 753   Galaxy Z Fold4  12.0    512.0   Black  Yes      1495.00   Flagship
# 983   Galaxy Z Fold4  12.0    512.0   Black  Yes      1922.93   Flagship
# 1106  Galaxy Z Flip4   8.0    512.0    Gray  Yes       797.00   Flagship
# 1225              X2  12.0    512.0   Black  Yes       327.99  Mid-range
# 1456              X2  12.0    512.0  Orange  Yes       670.07  Mid-range
# 1579      Galaxy S22  12.0    512.0   Black  Yes      1625.36   Flagship
# 1580      Galaxy S22  12.0    512.0   Green  Yes      1688.53   Flagship
# 1603  Galaxy Z Flip4   8.0    512.0    Blue  Yes      1169.66   Flagship
# 1604  Galaxy Z Flip4   8.0    512.0    Gray  Yes      1172.70   Flagship
# 1794  Galaxy Z Fold4  12.0    512.0   Green  Yes      1922.93   Flagship
#
#                                             Description
# 4     Nothing Phone (2) with 12GB of RAM and 512GB o...
# 32    Realme 11 Pro with 12GB of RAM and 512GB of st...
# 43    Realme 11 Pro with 12GB of RAM and 512GB of st...
# 95    Nothing Phone (2) with 12GB of RAM and 512GB o...
# 477   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...
# 661   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...
# 753   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...
# 983   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...
# 1106  Samsung Galaxy Z Flip4 with 8GB of RAM and 512...
# 1225  OPPO X2 with 12GB of RAM and 512GB of storage ...
# 1456  OPPO X2 with 12GB of RAM and 512GB of storage ...
# 1579  Samsung Galaxy S22 with 12GB of RAM and 512GB ...
# 1580  Samsung Galaxy S22 with 12GB of RAM and 512GB ...
# 1603  Samsung Galaxy Z Flip4 with 8GB of RAM and 512...
# 1604  Samsung Galaxy Z Flip4 with 8GB of RAM and 512...
# 1794  Samsung Galaxy Z Fold4 with 12GB of RAM and 51...

# %% [markdown]
# Custo por GB de armazenamento

# %%
#cria uma coluna 'price por GB, mapeando todas as linhas para definir o custo por GB de cada celular
phones['Price per GB'] = phones.apply(lambda row: row["Final Price"] / row['Storage'], axis=1)

# %%
#ordena o dataframe pelo preço por GB
phones.sort_values(by='Price per GB')
# Out:
#                                              Smartphone      Brand  \
# 1225              Oppo Find X2 Pro 12/512GB Negro Libre       OPPO
# 748            Oppo Find X2 Neo 12/256GB 5G Negro Libre       OPPO
# 1237            Oppo Find X2 Neo 12/256GB 5G Azul Libre       OPPO
# 1011           Oppo Reno 2 8/256GB Luminous Black Libre       OPPO
# 269                     TCL 40 SE 6/256GB Púrpura Libre        TCL
# ...                                                 ...        ...
# 1328               Crosscall CORE-M5 3/32GB Negro Libre  Crosscall
# 1351                        Funker W5.5 Pro 2/16GB Azul     Funker
# 1330                     Crosscall Core-X4 3/32GB Libre  Crosscall
# 1362         Hammer Explorer 3/32GB Negro/Naranja Libre     Hammer
# 1284  Nokia 5.4 4/64GB Noche Polar Libre Versión Imp...      Nokia
#
#             Model   RAM  Storage   Color Free  Final Price   Category  \
# 1225           X2  12.0    512.0   Black  Yes       327.99  Mid-range
# 748   Find X2 Neo  12.0    256.0   Black  Yes       189.00     Budget
# 1237  Find X2 Neo  12.0    256.0    Blue  Yes       189.00     Budget
# 1011       Reno 2   8.0    256.0   Black  Yes       198.00     Budget
# 269         40 SE   6.0    256.0  Purple  Yes       200.99     Budget
# ...           ...   ...      ...     ...  ...          ...        ...
# 1328      CORE-M5   3.0     32.0   Black  Yes       410.00  Mid-range
# 1351         W5.5   2.0     16.0    Blue   No       220.78     Budget
# 1330      Core-X4   3.0     32.0   Black  Yes       487.09  Mid-range
# 1362     Explorer   3.0     32.0  Orange  Yes       528.46  Mid-range
# 1284          5.4   4.0     64.0   Black  Yes      1499.00   Flagship
#
#                                             Description  Price per GB
# 1225  OPPO X2 with 12GB of RAM and 512GB of storage ...      0.640605
# 748   OPPO Find X2 Neo with 12GB of RAM and 256GB of...      0.738281
# 1237  OPPO Find X2 Neo with 12GB of RAM and 256GB of...      0.738281
# 1011  OPPO Reno 2 with 8GB of RAM and 256GB of stora...      0.773438
# 269   TCL 40 SE with 6GB of RAM and 256GB of storage...      0.785117
# ...                                                 ...           ...
# 1328  Crosscall CORE-M5 with 3GB of RAM and 32GB of ...     12.812500
# 1351  Funker W5.5 with 2GB of RAM and 16GB of storag...     13.798750
# 1330  Crosscall Core-X4 with 3GB of RAM and 32GB of ...     15.221562
# 1362  Hammer Explorer with 3GB of RAM and 32GB of st...     16.514375
# 1284  Nokia 5.4 with 4GB of RAM and 64GB of storage ...     23.421875
#
# [1333 rows x 11 columns]

# %% [markdown]
# Ordenar por preço e filtrar por marca

# %%
#ordenando por preço
phones.sort_values(by='Final Price')
# Out:
#                                              Smartphone    Brand  \
# 1052                      SPC Smart 2 1/16GB Rojo Libre      SPC
# 109                 Alcatel 1 (2021) 1/16GB Negro Libre  Alcatel
# 108                  Alcatel 1 (2021) 1/16GB Azul Libre  Alcatel
# 376            Xiaomi Redmi A2 2/32GB Verde Claro Libre   Xiaomi
# 536             Xiaomi Redmi A2 2/32GB Azul Claro Libre   Xiaomi
# ...                                                 ...      ...
# 477   Samsung Galaxy Z Fold4 12/512GB Negro Libre + ...  Samsung
# 661   Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
# 983   Samsung Galaxy Z Fold4 12/512GB Negro Libre + ...  Samsung
# 1794  Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
# 1380             Honor Magic4 Pro 5G 8/256GB Cian Libre    Honor
#
#                Model   RAM  Storage      Color Free  Final Price  Category  \
# 1052         Smart 2   1.0     16.0        Red  Yes        70.68    Budget
# 109         1 (2021)   1.0     16.0      Black  Yes        70.98    Budget
# 108         1 (2021)   1.0     16.0       Blue  Yes        70.98    Budget
# 376         Redmi A2   2.0     32.0      Green  Yes        77.98    Budget
# 536         Redmi A2   2.0     32.0       Blue  Yes        79.99    Budget
# ...              ...   ...      ...        ...  ...          ...       ...
# 477   Galaxy Z Fold4  12.0    512.0      Black  Yes      1919.00  Flagship
# 661   Galaxy Z Fold4  12.0    512.0      Green  Yes      1919.00  Flagship
# 983   Galaxy Z Fold4  12.0    512.0      Black  Yes      1922.93  Flagship
# 1794  Galaxy Z Fold4  12.0    512.0      Green  Yes      1922.93  Flagship
# 1380          Magic4   8.0    256.0  Turquoise  Yes      2271.28  Flagship
#
#                                             Description  Price per GB
# 1052  SPC Smart 2 with 1GB of RAM and 16GB of storag...      4.417500
# 109   Alcatel 1 (2021) with 1GB of RAM and 16GB of s...      4.436250
# 108   Alcatel 1 (2021) with 1GB of RAM and 16GB of s...      4.436250
# 376   Xiaomi Redmi A2 with 2GB of RAM and 32GB of st...      2.436875
# 536   Xiaomi Redmi A2 with 2GB of RAM and 32GB of st...      2.499687
# ...                                                 ...           ...
# 477   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...      3.748047
# 661   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...      3.748047
# 983   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...      3.755723
# 1794  Samsung Galaxy Z Fold4 with 12GB of RAM and 51...      3.755723
# 1380  Honor Magic4 with 8GB of RAM and 256GB of stor...      8.872188
#
# [1333 rows x 11 columns]

# %%
#filtrando por marca e então ordenando por preço
phones.query("Brand == 'Samsung'").sort_values(by='Final Price')
# Out:
#                                              Smartphone    Brand  \
# 1766  Samsung Galaxy A10 2/32GB Rojo Libre Versión I...  Samsung
# 1171              Samsung Galaxy A20e 3/32GB Azul Libre  Samsung
# 455              Samsung Galaxy A20e 3/32GB Negro Libre  Samsung
# 876   Samsung Galaxy A40 4/64GB Negro Libre Versión ...  Samsung
# 1265  Samsung Galaxy A40 4/64GB Azul Libre Versión I...  Samsung
# ...                                                 ...      ...
# 1293  Samsung Galaxy Z Fold4 12/256GB Verde Libre + ...  Samsung
# 661   Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
# 477   Samsung Galaxy Z Fold4 12/512GB Negro Libre + ...  Samsung
# 983   Samsung Galaxy Z Fold4 12/512GB Negro Libre + ...  Samsung
# 1794  Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
#
#                Model   RAM  Storage  Color Free  Final Price  Category  \
# 1766      Galaxy A10   2.0     32.0    Red  Yes        95.00    Budget
# 1171     Galaxy A20e   3.0     32.0   Blue  Yes        99.99    Budget
# 455      Galaxy A20e   3.0     32.0  Black  Yes       105.00    Budget
# 876       Galaxy A40   4.0     64.0  Black  Yes       120.00    Budget
# 1265      Galaxy A40   4.0     64.0   Blue  Yes       120.00    Budget
# ...              ...   ...      ...    ...  ...          ...       ...
# 1293  Galaxy Z Fold4  12.0    256.0  Green  Yes      1802.94  Flagship
# 661   Galaxy Z Fold4  12.0    512.0  Green  Yes      1919.00  Flagship
# 477   Galaxy Z Fold4  12.0    512.0  Black  Yes      1919.00  Flagship
# 983   Galaxy Z Fold4  12.0    512.0  Black  Yes      1922.93  Flagship
# 1794  Galaxy Z Fold4  12.0    512.0  Green  Yes      1922.93  Flagship
#
#                                             Description  Price per GB
# 1766  Samsung Galaxy A10 with 2GB of RAM and 32GB of...      2.968750
# 1171  Samsung Galaxy A20e with 3GB of RAM and 32GB o...      3.124687
# 455   Samsung Galaxy A20e with 3GB of RAM and 32GB o...      3.281250
# 876   Samsung Galaxy A40 with 4GB of RAM and 64GB of...      1.875000
# 1265  Samsung Galaxy A40 with 4GB of RAM and 64GB of...      1.875000
# ...                                                 ...           ...
# 1293  Samsung Galaxy Z Fold4 with 12GB of RAM and 25...      7.042734
# 661   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...      3.748047
# 477   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...      3.748047
# 983   Samsung Galaxy Z Fold4 with 12GB of RAM and 51...      3.755723
# 1794  Samsung Galaxy Z Fold4 with 12GB of RAM and 51...      3.755723
#
# [307 rows x 11 columns]

# %% [markdown]
# Calcular a Porcentagem de Smartphones com maior armazenamento

# %%
#atribui a uma variavel a soma dos celulares com o maior armazenamento (512gb)
soma_maiores_armazenamentos = maiores_armazenamentos.count()['Smartphone']

# %%
#atribui a uma variavel a soma de todos os celulares
total_celulares = phones.count()['Smartphone']

# %%
#calcula o percentual dos celulares com maior armazenamento com o total de celulares
percentual = (soma_maiores_armazenamentos/total_celulares) * 100

# %%
#imprime o percentual arredondado
round(percentual, 2)
# Out:
# 1.2

# %% [markdown]
# Calcular a porcentagem de smartphones com 64gb

# %%
#imprime todos os celulares com 64gb de armazenamento
celulares_64gb = phones.query("Storage == 64")

# %%
#atribui a uma variável a soma de todos esses celulares e imprime
soma_celulares_64gb = celulares_64gb.count()['Smartphone']
soma_celulares_64gb
# Out:
# 260

# %%
#atribui a uma variável o percentual dos celulares com 64gb em relação ao total de celulares
percentual = (soma_celulares_64gb/total_celulares) * 100

# %%
#imprime o percentual arredondado
round(percentual, 2)
# Out:
# 19.5

# %% [markdown]
# percentual de celulares de cada categoria

# %%
#atribui a uma variavel o total de celulares na categoria 'budget'
celulares_baratos = len(phones.query("Category == 'Budget'"))
celulares_baratos
# Out:
# 699

# %%
#atribui a uma variavel o total de celulares na categoria 'mid-range'
celulares_medios = len(phones.query("Category == 'Mid-range'"))
celulares_medios
# Out:
# 475

# %%
#atribui a uma variavel o total de celulares na categoria 'flagship'
celulares_caros = len(phones.query("Category == 'Flagship'"))
celulares_caros
# Out:
# 159

# %%
#atribui a uma variável a relação de celulares budget em comparação com o total e imprime o valor arredondado
relacao_baratos = (celulares_baratos/total_celulares) * 100
round(relacao_baratos, 2)
# Out:
# 52.44

# %%
#atribui a uma variável a relação de celulares mid-range em comparação com o total e imprime o valor arredondado
relacao_medios = (celulares_medios/total_celulares) * 100
round(relacao_medios, 2)
# Out:
# 35.63

# %%
#atribui a uma variável a relação de celulares flagship em comparação com o total e imprime o valor arredondado
relacao_caros = (celulares_caros/total_celulares) * 100
round(relacao_caros, 2)
# Out:
# 11.93

# %% [markdown]
# Salvando a nova base de dados

# %%
#importa a base de dados 'phones' para um novo arquivo CSV
phones.to_csv('smartphones_enhanced.csv')

# %%
#faz a leitura do novo arquivo CSV 
pd.read_csv('smartphones_enhanced.csv')
# Out:
#       Unnamed: 0                                        Smartphone     Brand  \
# 0              0                Realme C55 8/256GB Sunshower Libre    Realme
# 1              1          Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2              2      Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3              3          Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              4           Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...          ...                                               ...       ...
# 1328        1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1329        1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1330        1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1331        1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1332        1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price  Category  \
# 0                C55   8.0    256.0  Yellow  Yes       231.60    Budget
# 1         Galaxy M23   4.0    128.0    Blue  Yes       279.00    Budget
# 2           Moto G13   4.0    128.0    Blue  Yes       179.01    Budget
# 3     Redmi Note 11S   6.0    128.0    Gray  Yes       279.99    Budget
# 4          Phone (2)  12.0    512.0   White  Yes       799.00  Flagship
# ...              ...   ...      ...     ...  ...          ...       ...
# 1328    Redmi Note 8   4.0     64.0    Blue  Yes       249.01    Budget
# 1329   Redmi Note 8T   4.0    128.0    Blue  Yes       200.00    Budget
# 1330    Redmi Note 9   4.0    128.0   White  Yes       269.00    Budget
# 1331         Note 9S   4.0     64.0    Gray  Yes       211.00    Budget
# 1332         Note 9S   6.0    128.0    Gray  Yes       289.00    Budget
#
#                                             Description  Price per GB
# 0     Realme C55 with 8GB of RAM and 256GB of storag...      0.904687
# 1     Samsung Galaxy M23 with 4GB of RAM and 128GB o...      2.179688
# 2     Motorola Moto G13 with 4GB of RAM and 128GB of...      1.398516
# 3     Xiaomi Redmi Note 11S with 6GB of RAM and 128G...      2.187422
# 4     Nothing Phone (2) with 12GB of RAM and 512GB o...      1.560547
# ...                                                 ...           ...
# 1328  Xiaomi Redmi Note 8 with 4GB of RAM and 64GB o...      3.890781
# 1329  Xiaomi Redmi Note 8T with 4GB of RAM and 128GB...      1.562500
# 1330  Xiaomi Redmi Note 9 with 4GB of RAM and 128GB ...      2.101562
# 1331  Xiaomi Note 9S with 4GB of RAM and 64GB of sto...      3.296875
# 1332  Xiaomi Note 9S with 6GB of RAM and 128GB of st...      2.257812
#
# [1333 rows x 12 columns]
