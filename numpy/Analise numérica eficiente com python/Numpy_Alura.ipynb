# %% [markdown]
# **Carregando os dados**

# %%
#importa a biblioteca numpy
import numpy as np

# %%
#carrega o arquivo CSV, delimitando por vírgula e pulando a primeira coluna
dados = np.loadtxt('apples_ts.csv', delimiter = ',', usecols = np.arange(1, 88, 1))

# %% [markdown]
# Dimensões dos arrays

# %%
#imprime a variável
dados
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %%
#imprim a quantidade de dimensões em que os dados estão variando
#nesse caso, linhas e colunas
dados.ndim
# Out:
# 2

# %%
#imprime a quantidade de números na tabela
dados.size
# Out:
# 522

# %%
#imprime a quantidade de linhas e colunas
datas = dados.shape
datas
# Out:
# (6, 87)

# %%
#transforma as linhas e colunas (transposição)
dados_transpostos = dados.T
dados_transpostos
# Out:
# array([[  1.2013,  79.72  ,  42.67  ,  62.55  ,  48.26  ,  71.25  ],
#        [  2.2013,  81.08  ,  44.37  ,  62.73  ,  51.01  ,  71.35  ],
#        [  3.2013,  79.68  ,  44.73  ,  63.43  ,  50.91  ,  70.9   ],
#        [  4.2013,  79.8   ,  46.75  ,  63.83  ,  53.94  ,  71.92  ],
#        [  5.2013,  80.63  ,      nan,  66.06  ,  61.27  ,  72.91  ],
#        [  6.2013,  80.8   ,  51.59  ,  69.22  ,  65.44  ,  74.39  ],
#        [  7.2013,  80.28  ,  57.8   ,  72.07  ,  56.51  ,  73.1   ],
#        [  8.2013,  78.99  ,  62.14  ,  69.31  ,  53.    ,  70.24  ],
#        [  9.2013,  76.77  ,  56.76  ,  65.18  ,  43.87  ,  69.12  ],
#        [ 10.2013,  76.09  ,  50.85  ,  62.13  ,  42.12  ,  68.98  ],
#        [ 11.2013,  76.36  ,  46.43  ,  64.17  ,  43.98  ,  68.58  ],
#        [ 12.2013,  77.16  ,  46.73  ,  65.5   ,  44.66  ,  69.5   ],
#        [  1.2014,  77.5   ,  45.85  ,  66.85  ,  47.73  ,  70.14  ],
#        [  2.2014,  79.03  ,  49.25  ,  68.38  ,  52.31  ,  70.58  ],
# ...

# %% [markdown]
# Visualização e seleção

# %%
#seleciona todas suas linhas e apenas a primeira coluna 
datas = dados_transpostos[:, 0]

# %%
#seleciona a linha de preços
precos = dados_transpostos[:,1:6]

# %%
import matplotlib.pyplot as plt

# %%
#necessário para o gráfico ficar coerente
datas = np.arange(1, 88, 1)

# %%
#mostra o gráfico contendo a variação de preço por data em Moscow
plt.plot(datas, precos[:,0])

# %%
#cria um array de preços de cada cidade
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Krasnodar = precos[:,3]
Ekateringurg = precos[:,4]

# %%
Moscow
# Out:
# array([ 79.72,  81.08,  79.68,  79.8 ,  80.63,  80.8 ,  80.28,  78.99,
#         76.77,  76.09,  76.36,  77.16,  77.5 ,  79.03,  80.28,  80.05,
#         78.11,  76.9 ,  77.68,  76.05,  75.53,  73.39,  78.36,  89.16,
#        105.43, 104.82, 101.15,  98.63,  99.96,  97.29,  98.64, 104.26,
#        102.63,  98.64,  97.17,  98.09, 103.07, 110.26, 110.84, 112.28,
#        111.1 , 110.06, 113.7 , 112.88, 102.08,  95.54,  91.33,  89.99,
#         91.44,  93.51,  93.6 ,  93.78,  98.91, 121.76, 129.6 , 127.9 ,
#        114.55, 101.88,  99.09, 103.35, 106.58, 108.  , 114.95, 121.17,
#        122.48, 127.58, 131.89, 129.36, 104.26,  93.45,  92.93,  96.15,
#         99.1 , 103.  , 103.31, 103.01, 107.37, 116.91, 125.29, 123.94,
#        113.03, 102.19,  97.83, 101.07, 103.44, 108.23, 110.28])

# %% [markdown]
# **Comparação entre arrays**

# %%
 #mostra o tipo de array, no caso um array unidimensional
 Moscow.shape
# Out:
# (87,)

# %%
#cria uma variável contendo os preços de cada ano da cidade Moscow
Moscow_ano1 = Moscow[0:12]
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]

# %%
plt.plot(np.arange(1,13,1),Moscow_ano1)
plt.plot(np.arange(1,13,1),Moscow_ano2)
plt.plot(np.arange(1,13,1),Moscow_ano3)
plt.plot(np.arange(1,13,1),Moscow_ano4)
#a função legend adiciona uma legenda ao grafico
plt.legend(["ano 1", "ano 2", "ano 3", "ano 4"])

# %%
#'array_equal' verifica se dois arrays são iguais
np.array_equal(Moscow_ano3, Moscow_ano4)
# Out:
# False

# %%
#'allclose' verifica se arrays são próximos
np.allclose(Moscow_ano3, Moscow_ano4, 10)
# Out:
# True

# %% [markdown]
# Lidando com NaNs

# %%
#exibe o gráfico com dado NaN
plt.plot(datas, Kaliningrad)

# %%
#possui um dado NaN
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
#'isnan' verifica valores não numéricos
sum(np.isnan(Kaliningrad))
# Out:
# 1

# %%
#'mean' calcula a média
#atribui ao valor NaN a média do valor antecessor e do valor sucessor a ele
Kaliningrad[4] = np.mean([Kaliningrad[3], Kaliningrad[5]])

# %%
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,  49.17,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
#média do preço das maças de moscow
np.mean(Moscow)
# Out:
# 98.79781609195402

# %%
#média do preço das maças de Kaliningrad
np.mean(Kaliningrad)
# Out:
# 74.5506896551724

# %% [markdown]
# Exercício:
# Continuando com o projeto das laranjas/toranjas agora você deve selecionar parte dos dados. As colunas que iremos avaliar são as de diâmetro e peso. Crie arrays específicos para guardar o diâmetro e peso da laranja e toranja. O diâmetro está na coluna zero e o peso na coluna 1. Os dados referentes a laranja vão até a linha 4999 e os referentes à toranja iniciam na linha 5000 do arquivo.
#
# Após fazer a seleção de dados, importe a biblioteca matplotlib e crie um gráfico para a laranja e para a toranja do peso pelo diâmetro.

# %% [markdown]
# Exercício:
# Continuando com o projeto das laranjas/toranjas agora você deve selecionar parte dos dados. As colunas que iremos avaliar são as de diâmetro e peso. Crie arrays específicos para guardar o diâmetro e peso da laranja e toranja. O diâmetro está na coluna zero e o peso na coluna 1. Os dados referentes a laranja vão até a linha 4999 e os referentes à toranja iniciam na linha 5000 do arquivo.
#
# Após fazer a seleção de dados, importe a biblioteca matplotlib e crie um gráfico para a laranja e para a toranja do peso pelo diâmetro.

# %%
#importa os dados do arquivo citrus.csv, começando a partir da segunda coluna e indo até a quarta, pulando a primeira linha.
dados_citrus = np.loadtxt("citrus.csv", delimiter=",", usecols=(np.arange(1, 4, 1)), skiprows=1)

# %%
#guarda as primeiras 5.000 linhas da primeira coluna (diametro)
diametro_laranjas = dados_citrus[:5000,0]
#guarda as primeiras 5.000 linhas da segunda coluna (peso)
peso_laranjas = dados_citrus[:5000,1]

# %%
#variável diametro_toranjas guarda as ultimas 5.000 linhas da primeira coluna (diametro)
diametro_toranjas = dados_citrus[5000:,0]
#guarda as ultimas 5.000 linhas da segunda coluna (peso)
peso_toranjas = dados_citrus[5000:,1]

# %%
#exibe um gráfico do peso das laranjas pelo diametro das laranjas
plt.plot(peso_laranjas, diametro_laranjas)
#exibe um gráfico do peso das toranjas pelo diametro das toranjas
plt.plot(peso_toranjas, diametro_toranjas)

# %% [markdown]
# **operações entre arrays**

# %%
#exibe o gráfico das vendas de moscow
plt.plot(Moscow)

# %% [markdown]
# **Equação da reta: y=ax+b**

# %%
x = datas

# %%
#queremos fazer uma reta para mensurar o crescimento no preço
# chutando um número para A
y = 2*x + 80

# %%
#gráfico com as datas pelos preços de Moscow
plt.plot(datas, Moscow)
#gráfico com a reta de crescmento (y = ax + b)
plt.plot(x, y)
#resultado: reta pouco alinhada com os valores reais

# %%
#"np.power" eleva o número ao valor especificado na função (no caso, 2)
#"np.sqrt" pega a raiz quadrada do valor
# quanto menor o número do resultado, melhor o ajuste da reta
np.sqrt(np.sum(np.power(Moscow-y, 2)))
# Out:
# 749.2329171225728

# %%
#chuta um valor menor para A, agora tendo como base a reta resultante do chute anterior
y = 0.52*x+80

# %%
#gráfico com as datas pelos preços de Moscow
plt.plot(datas, Moscow)
#gráfico com a reta de crescmento (y = ax + b)
plt.plot(x, y)
#resultado: reta bem mais alinhada que anteriormente

# %%
# quanto menor o número do resultado, melhor o ajuste da reta
np.sqrt(np.sum(np.power(Moscow-y, 2)))
#resultado: valor bem menor que o valor enterior, resultando em uma maior precisão.
# Out:
# 110.48504740461489

# %%
#"np.linalg.norm" resume a operação acima, assim utilizando apenas uma função
#calcula a norma entre 2 arrays da numpy
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %% [markdown]
# **Multiplicação**

# %% [markdown]
# **Calculando o coeficiente angular**
#
# a = coeficiente angular
#
# n = numero de elementos
#
# Y = Moscow
#
# X = datas
#
# o coeficiente angular pode ser obtido usando a equação:
#
# ![image.png](attachment:image.png)

# %%
Y = Moscow
X = datas
#quantidade de elementos na tabela Moscow
n = np.size(Moscow)

# %%
#eleva todos os elementos da tabela datas ao quadrado e retorna a quantidade~de linhas e colunas
(X**2).shape
# Out:
# (87,)

# %%
#equação para obter o coeficiente angular
a = (n*np.sum(X * Y) - np.sum(X) * np.sum(Y))/(n*np.sum(x**2) - np.sum(x)**2)

# %% [markdown]
# calculando o coeficiente linear (B)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#equação para obter o coeficiente linear
b = np.mean(Y) - a * np.mean(X)

# %%
#agora sim, podemos solucionar a equação da reta
y = a*X+b

# %%
#valor caiu de ~110 para ~101, o que mostra uma melhora considerável
np.linalg.norm(Moscow-y)
# Out:
# 101.7969539992751

# %%
#exibe a relação de preço por data em Moscow
plt.plot(datas, Moscow)
#exibe a reta que exibe o crescimento no preço 
plt.plot(x, y)

# %% [markdown]
# Thaís queria desenhar um círculo com a ajuda do computador. Para desenhar a parte superior do círculo ela sabia que deveria usar a equação:
#
# ![image.png](attachment:image.png)
#
# E para a parte inferior bastava utilizar a mesma equação multiplicada por -1.

# %%
'''import numpy as np
import matplotlib.pyplot as plt

# Gerar uma sequência de valores de x de -1 a 1
x = np.arange(-1, 1.01, 0.0001)

# Implementação da fórmula
y1 = np.sqrt(1 - x**2)
y2 = -np.sqrt(1 - x**2)

# Plotar o gráfico com as duas partes do círculo
plt.plot(x, y1, 'r')
plt.plot(x, y2, 'r' )

# Adicionar o título do gráfico e os rótulos dos eixos x e y
plt.title("Círculo")
plt.xlabel("Eixo x")
plt.ylabel("Eixo y")

# Exibir o gráfico
plt.show()'''
# Out:
# 'import numpy as np\nimport matplotlib.pyplot as plt\n\n# Gerar uma sequência de valores de x de -1 a 1\nx = np.arange(-1, 1.01, 0.0001)\n\n# Implementação da fórmula\ny1 = np.sqrt(1 - x**2)\ny2 = -np.sqrt(1 - x**2)\n\n# Plotar o gráfico com as duas partes do círculo\nplt.plot(x, y1, \'r\')\nplt.plot(x, y2, \'r\' )\n\n# Adicionar o título do gráfico e os rótulos dos eixos x e y\nplt.title("Círculo")\nplt.xlabel("Eixo x")\nplt.ylabel("Eixo y")\n\n# Exibir o gráfico\nplt.show()'

# %% [markdown]
# **Motivos da regressão**

# %%
plt.plot(datas, Moscow)
plt.plot(x, y)
#calculando o preço na metade do mês 41
plt.plot(41.5, 41.5*a+b, "*r")
#também pode-se estimar o preço em um mês futuro
plt.plot(100, 100*a+b, "*r")

# %% [markdown]
# **Chegou a hora de você testar os conhecimentos desenvolvidos durante a aula. Continuando com o projeto das laranjas/toranjas agora você deve calcular o coeficiente ângular e o linear para a reta da laranja e para a reta da toranja. Use a fórmula de mínimos quadrados para encontrar cada um.**

# %%
#guarda as primeiras 5.000 linhas da primeira coluna (diametro)
diametro_laranjas = dados_citrus[:5000,0]
#guarda as primeiras 5.000 linhas da segunda coluna (peso)
peso_laranjas = dados_citrus[:5000,1]

# %%
#variável diametro_toranjas guarda as ultimas 5.000 linhas da primeira coluna (diametro)
diametro_toranjas = dados_citrus[5000:,0]
#guarda as ultimas 5.000 linhas da segunda coluna (peso)
peso_toranjas = dados_citrus[5000:,1]

# %%
#exibe um gráfico do peso das laranjas pelo diametro das laranjas
plt.plot(peso_laranjas, diametro_laranjas)

# %%
#exibe um gráfico do peso das toranjas pelo diametro das toranjas
plt.plot(peso_toranjas, diametro_toranjas)

# %%
Y1 = peso_laranjas
X1 = diametro_laranjas
n1 = np.size(X1)

# %%
a1 = n1 * np.sum(X1 * Y1) - np.sum(X1) * np.sum(Y1) / (n1 * np.sum(X1**2) - np.sum(X1)**2)

# %%
b1 = np.mean(Y1) - a1 * np.mean(X1)

# %%
y = a1* + X1 + b1

# %% [markdown]
# **Número aleatórios**

# %%
#função para imprimir 100 números aleatórios entre 40 e 100
np.random.randint(low=40, high=100, size=100)
# Out:
# array([69, 94, 80, 99, 41, 64, 92, 97, 55, 94, 82, 68, 91, 51, 87, 72, 53,
#        90, 68, 83, 56, 92, 50, 45, 87, 55, 89, 66, 93, 55, 77, 40, 44, 65,
#        79, 71, 90, 41, 70, 86, 41, 58, 48, 50, 40, 42, 70, 68, 47, 56, 83,
#        82, 63, 74, 44, 63, 54, 56, 90, 71, 89, 43, 55, 58, 74, 58, 40, 43,
#        63, 79, 45, 77, 46, 68, 64, 60, 40, 51, 68, 61, 51, 54, 50, 88, 59,
#        71, 63, 53, 45, 61, 63, 45, 46, 56, 85, 64, 49, 60, 49, 76])

# %%
#atribui a 'coef_angulares' uma função para imprimir 100 números aleatórios entre 0.10 e 0.90
coef_angulares = np.random.uniform(low=0.10, high=0.90, size=100)

# %%
norma = np.array([])
for i in range(100):
    norma= np.append(norma, np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))

# %%
norma
# Out:
# array([149.24986335, 173.99433908, 205.83098617, 117.89052044,
#        106.12999108, 161.36642917, 111.6759784 , 141.15138331,
#        115.51449936, 112.24945516, 198.51913489, 104.07694528,
#        112.77081316, 103.89606603, 123.0994978 , 128.39886418,
#        174.13062486, 207.86491862, 114.15446881, 136.07807167,
#        123.05003425, 208.12067012, 180.0797547 , 111.95776275,
#        134.56066651, 204.46503892, 186.63483026, 186.21580709,
#        136.39589944, 103.83648057, 221.2690596 , 235.38760518,
#        178.82522058, 104.73833764, 113.10473652, 128.25236535,
#        150.00541168, 230.33112401, 101.87883682, 102.69758668,
#        103.60155754, 106.39659581, 108.36620192, 187.4952406 ,
#        189.23292841, 155.66204534, 116.75089907, 102.06588985,
#        138.30543084, 203.86116932, 170.48315403, 203.68518503,
#        173.11468654, 172.91510189, 130.71852872, 160.43682607,
#        159.99299913, 160.35334889, 161.5750182 , 180.34580235,
# ...
